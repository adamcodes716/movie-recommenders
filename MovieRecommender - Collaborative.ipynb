# %% [markdown]
# This is an example of a collaborative approach to movie recommendations.  A dataset containing a list of movies is created, and then another data set
# containing a single person's reviews is passed in.  The code then finds the nearest neighbors to that user (e.g. people that like the same movies).
# It then predicts movies that the user will like based on their neighbor's likes.

# %% [markdown]
# # Create a virtual environment.  Optional, only needs to be done once.  MUST BE RUN IN THE TERMINAL
# python -m venv .venv
#
# # Active the environment.  On MacOS, WSL, Linux
# source .venv/bin/activate
# # Activiate the environment  On Windows
# .\.venv\Scripts\activate

# %%
# The next line only needs to be run once
# %pip install lenskit
import lenskit.datasets as ds
import pandas as pd

###  NOTE!  if changing the data set, be sure to also change the "minimum_to_include" value.  E.g. if large dataset, prob set the min to thousands
#base_data_path = "sample-data-small/"
base_data_path = "sample-data-large/"  # folder containing larger set of user reviews

#data = ds.MovieLens('sample-data-small/')
# use the next line for large dataset (25 mill reviews).  You can find this set at https://grouplens.org/datasets/movielens/25m/
data = ds.MovieLens(base_data_path)

ratings = data.ratings
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: lenskit in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (0.14.3)
# Requirement already satisfied: pandas>=1.0 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from lenskit) (2.2.0)
# Requirement already satisfied: numpy>=1.17 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from lenskit) (1.26.4)
# Requirement already satisfied: scipy>=1.2 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from lenskit) (1.12.0)
# Requirement already satisfied: numba<0.59,>=0.51 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from lenskit) (0.58.1)
# Requirement already satisfied: cffi>=1.12.2 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from lenskit) (1.16.0)
# Requirement already satisfied: psutil>=5 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from lenskit) (5.9.8)
# Requirement already satisfied: binpickle>=0.3.2 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from lenskit) (0.3.4)
# Requirement already satisfied: seedbank>=0.1.0 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from lenskit) (0.1.3)
# Requirement already satisfied: csr>=0.3.1 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from lenskit) (0.5.1)
# Requirement already satisfied: msgpack>=1.0 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from binpickle>=0.3.2->lenskit) (1.0.7)
# Requirement already satisfied: pycparser in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from cffi>=1.12.2->lenskit) (2.21)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from numba<0.59,>=0.51->lenskit) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from pandas>=1.0->lenskit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from pandas>=1.0->lenskit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from pandas>=1.0->lenskit) (2023.4)
# Requirement already satisfied: anyconfig==0.13.* in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from seedbank>=0.1.0->lenskit) (0.13.0)
# Requirement already satisfied: setuptools in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from anyconfig==0.13.*->seedbank>=0.1.0->lenskit) (65.5.0)
# Requirement already satisfied: six>=1.5 in c:\projects\machine learning\movie-recommender\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0->lenskit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# MovieLens stores a user's ID number (the first row few rows look like they're all ratings from user 1), the item's ID (in this case each ID is a different movie)
#
# Step 1.2

# %%
rows_to_show = 10   # <-- Change this number to get back more or less recommendations
data.ratings.head(rows_to_show)  # <-- Try changing "ratings" to "movies", "tags", or "links" to see the kinds of data that's stored in the other MovieLens files
# Out:
#    user  item  rating   timestamp
# 0     1   296     5.0  1147880044
# 1     1   306     3.5  1147868817
# 2     1   307     5.0  1147868828
# 3     1   665     5.0  1147878820
# 4     1   899     3.5  1147868510
# 5     1  1088     4.0  1147868495
# 6     1  1175     3.5  1147868826
# 7     1  1217     3.5  1147878326
# 8     1  1237     5.0  1147868839
# 9     1  1250     4.0  1147868414

# %% [markdown]
# Pull in genre and title from the "movies" file

# %%
joined_data = data.ratings.join(data.movies['genres'], on='item')
joined_data = joined_data.join(data.movies['title'], on='item')
joined_data.head(rows_to_show)
# Out:
#    user  item  rating   timestamp                       genres  \
# 0     1   296     5.0  1147880044  Comedy|Crime|Drama|Thriller
# 1     1   306     3.5  1147868817                        Drama
# 2     1   307     5.0  1147868828                        Drama
# 3     1   665     5.0  1147878820             Comedy|Drama|War
# 4     1   899     3.5  1147868510       Comedy|Musical|Romance
# 5     1  1088     4.0  1147868495        Drama|Musical|Romance
# 6     1  1175     3.5  1147868826         Comedy|Drama|Romance
# 7     1  1217     3.5  1147878326                    Drama|War
# 8     1  1237     5.0  1147868839                        Drama
# 9     1  1250     4.0  1147868414          Adventure|Drama|War
#
#                                               title
# 0                               Pulp Fiction (1994)
# 1  Three Colors: Red (Trois couleurs: Rouge) (1994)
# 2  Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 3                                Underground (1995)
# 4                        Singin' in the Rain (1952)
# 5                              Dirty Dancing (1987)
# 6                               Delicatessen (1991)
# 7                                        Ran (1985)
# 8   Seventh Seal, The (Sjunde inseglet, Det) (1957)
# 9              Bridge on the River Kwai, The (1957)

# %% [markdown]
# The movies and ratings have now been loaded.

# %% [markdown]
# ***STEP 2***
#
# Show a list of the top rated movies
#
# **Step 2.1**

# %%
average_ratings = (data.ratings).groupby(['item']).mean()
sorted_avg_ratings = average_ratings.sort_values(by="rating", ascending=False)
joined_data = sorted_avg_ratings.join(data.movies['genres'], on='item')
joined_data = joined_data.join(data.movies['title'], on='item')
joined_data = joined_data[joined_data.columns[1:]]

print("RECOMMENDED FOR ANYBODY:")
joined_data.head(rows_to_show)
# Out:
# RECOMMENDED FOR ANYBODY:
#         rating     timestamp                                genres  \
# item
# 136782     5.0  1.558738e+09                              Thriller
# 186119     5.0  1.558738e+09                              Children
# 137032     5.0  1.436144e+09                        Drama|Thriller
# 184643     5.0  1.558738e+09                              Thriller
# 137038     5.0  1.436144e+09                        Drama|Thriller
# 197231     5.0  1.558738e+09  Crime|Drama|Mystery|Romance|Thriller
# 184669     5.0  1.558738e+09                                Horror
# 137048     5.0  1.436145e+09                                 Drama
# 137050     5.0  1.436145e+09                              Thriller
# 137052     5.0  1.436145e+09                        Drama|Thriller
#
#                                 title
# item
# 136782  The Girl is in Trouble (2015)
# 186119            A Gift Horse (2015)
# 137032    The Perfect Neighbor (2005)
# 184643              Relentless (2018)
# 137038        The Perfect Wife (2001)
# 197231              The Harrow (2016)
# 184669         Devil's Whisper (2017)
# 137048           Perfect Child (2007)
# 137050               The Rival (2006)
# 137052       A Job to Kill For (2006)

# %% [markdown]
# There are several rare movies here.  It could be the result of having a limited number of reviews.
# Add a "count" column to see how many reviews there are for each movie.

# %%
average_ratings = (data.ratings).groupby('item') \
       .agg(count=('user', 'size'), rating=('rating', 'mean')) \
       .reset_index()

sorted_avg_ratings = average_ratings.sort_values(by="rating", ascending=False)
joined_data = sorted_avg_ratings.join(data.movies['genres'], on='item')
joined_data = joined_data.join(data.movies['title'], on='item')
joined_data = joined_data[joined_data.columns[1:]]


print("RECOMMENDED FOR ANYBODY:")
joined_data.head(rows_to_show)
# Out:
# RECOMMENDED FOR ANYBODY:
#        count  rating                                genres  \
# 29523      1     5.0                              Thriller
# 49654      1     5.0                              Children
# 29643      1     5.0                        Drama|Thriller
# 49041      1     5.0                              Thriller
# 29646      1     5.0                        Drama|Thriller
# 54556      1     5.0  Crime|Drama|Mystery|Romance|Thriller
# 49052      1     5.0                                Horror
# 29651      1     5.0                                 Drama
# 29652      1     5.0                              Thriller
# 29653      1     5.0                        Drama|Thriller
#
#                                title
# 29523  The Girl is in Trouble (2015)
# 49654            A Gift Horse (2015)
# 29643    The Perfect Neighbor (2005)
# 49041              Relentless (2018)
# 29646        The Perfect Wife (2001)
# 54556              The Harrow (2016)
# 49052         Devil's Whisper (2017)
# 29651           Perfect Child (2007)
# 29652               The Rival (2006)
# 29653       A Job to Kill For (2006)

# %% [markdown]
# We probably don't want movies that don't have many reviews
#
# **Step 2.2**

# %%
minimum_to_include = 50000 #<-- You can try changing this minimum to include movies rated by fewer or more people

average_ratings = (data.ratings).groupby(['item']).mean()
rating_counts = (data.ratings).groupby(['item']).count()
average_ratings = average_ratings.loc[rating_counts['rating'] > minimum_to_include]
sorted_avg_ratings = average_ratings.sort_values(by="rating", ascending=False)
joined_data = sorted_avg_ratings.join(data.movies['genres'], on='item')
joined_data = joined_data.join(data.movies['title'], on='item')
joined_data = joined_data[joined_data.columns[3:]]

print("RECOMMENDED FOR ANYBODY (minimum " + str(minimum_to_include) + " reviews ):")
joined_data.head(rows_to_show)
# Out:
# RECOMMENDED FOR ANYBODY (minimum 50000 reviews ):
#                            genres  \
# item
# 318                   Crime|Drama
# 858                   Crime|Drama
# 50         Crime|Mystery|Thriller
# 527                     Drama|War
# 2959  Action|Crime|Drama|Thriller
# 296   Comedy|Crime|Drama|Thriller
# 2571       Action|Sci-Fi|Thriller
# 593         Crime|Horror|Thriller
# 1196      Action|Adventure|Sci-Fi
# 1198             Action|Adventure
#
#                                                   title
# item
# 318                    Shawshank Redemption, The (1994)
# 858                               Godfather, The (1972)
# 50                           Usual Suspects, The (1995)
# 527                             Schindler's List (1993)
# 2959                                  Fight Club (1999)
# 296                                 Pulp Fiction (1994)
# 2571                                 Matrix, The (1999)
# 593                    Silence of the Lambs, The (1991)
# 1196  Star Wars: Episode V - The Empire Strikes Back...
# 1198  Raiders of the Lost Ark (Indiana Jones and the...

# %% [markdown]
# Lets show the top movies for someone looking for a specific genre

# %%
genre = "Drama"
average_ratings = (data.ratings).groupby(['item']).mean()
rating_counts = (data.ratings).groupby(['item']).count()
average_ratings = average_ratings.loc[rating_counts['rating'] > minimum_to_include]
average_ratings = average_ratings.join(data.movies['genres'], on='item')
average_ratings = average_ratings.loc[average_ratings['genres'].str.contains(genre)]

sorted_avg_ratings = average_ratings.sort_values(by="rating", ascending=False)
joined_data = sorted_avg_ratings.join(data.movies['title'], on='item')
joined_data = joined_data[joined_data.columns[3:]]
print("RECOMMENDED FOR A " + genre.upper() + " MOVIE FAN (minimum " + str(minimum_to_include) + " reviews ):")
joined_data.head(rows_to_show)
# Out:
# RECOMMENDED FOR A DRAMA MOVIE FAN (minimum 50000 reviews ):
#                               genres  \
# item
# 318                      Crime|Drama
# 858                      Crime|Drama
# 527                        Drama|War
# 2959     Action|Crime|Drama|Thriller
# 296      Comedy|Crime|Drama|Thriller
# 2858                   Drama|Romance
# 7153  Action|Adventure|Drama|Fantasy
# 356         Comedy|Drama|Romance|War
# 110                 Action|Drama|War
#
#                                                   title
# item
# 318                    Shawshank Redemption, The (1994)
# 858                               Godfather, The (1972)
# 527                             Schindler's List (1993)
# 2959                                  Fight Club (1999)
# 296                                 Pulp Fiction (1994)
# 2858                             American Beauty (1999)
# 7153  Lord of the Rings: The Return of the King, The...
# 356                                 Forrest Gump (1994)
# 110                                   Braveheart (1995)

# %% [markdown]
# STEP 3
#
# Step 3 is personalizing our recommender system AI based on a user's reviews. The sample format can be found here: https://github.com/adamcodes716/movie-recommenders/sample-data-small/sample-movie-ratings/.csv
#
# This data needs to be in a specific format (see here:  https://lkpy.lenskit.org/en/stable/interfaces.html#lenskit.algorithms.Recommender.recommend).
# This script has been updated to use "Rating10" column, which is base 10.  We need to divide by 2 to get base 5.
#
# Step 3.1

# %% [markdown]
# My ratings are out of 10 and this exercise requires ratings out of 5.  We will perform some match using "Rating10" to get a base 5 rating.
# I left base 5 code in this next cell if your ratings file is base 5.

# %%
import csv

reviewer1_rating_dict = {}
reviewer2_rating_dict = {}  #optional, if you wanted to try to find a movie for two people using their reviews

path = base_data_path + "reviewer1-movie-ratings.csv"

with open(path, newline='') as csvfile:
  ratings_reader = csv.DictReader(csvfile)
  for row in ratings_reader:
     # Use this block if ratings are base 5
    # if ((row['ratings'] != "") and (float(row['ratings']) > 0) and (float(row['ratings']) < 6)):
    #   reviewer1_rating_dict.update({int(row['item']): float(row['ratings'])})
    # Use this block if ratings are base 10
     if ((row['ratings'] != "") and (float(row['ratings']) > 0) and (float(row['ratings']) < 11)):
       reviewer1_rating_dict.update({int(row['item']): round(float(row['ratings']) / 2, 2)})  


    
    
# this section is only needed if you are trying to find a movie for 2 reviewers. They would be combined later into single DF     
# path = base_data_path + "reviewer2-movie-ratings.csv"
# with open(path, newline='') as csvfile:
#    ratings_reader = csv.DictReader(csvfile)
#    for row in ratings_reader:
#      # Use this block if ratings are base 5
#      # if ((row['ratings'] != "") and (float(row['ratings']) > 0) and (float(row['ratings']) < 6)):
#      #   reviewer1_rating_dict.update({int(row['item']): float(row['ratings'])})
#      # Use this block if ratings are base 10
#      if ((row['ratings'] != "") and (float(row['ratings']) > 0) and (float(row['ratings']) < 11)):
#       reviewer2_rating_dict.update({int(row['item']): round(float(row['ratings']) / 2, 2)})  



     
print("Rating dictionaries assembled!")
print("Sanity check:")
print("\tReviewer 1's rating for the first movie is " + str(list(reviewer1_rating_dict.values())[0]))
# Out:
# Rating dictionaries assembled!
# Sanity check:
# 	Reviewer 1's rating for the first movie is 3.5

# %% [markdown]
# Step 4
# We will use UserUser from Lenskit to try to find reviewers (neighbors) that like the same movies that I like.
# As part of this search, we will set a max and min number of neighbors.

# %%
from lenskit.algorithms import Recommender
from lenskit.algorithms.user_knn import UserUser

num_recs = 100  #<---- This is the number of recommendations to generate. You can change this if you want to see more recommendations

user_user = UserUser(15, min_nbrs=3) #These two numbers set the minimum (3) and maximum (15) number of neighbors to consider. These are considered "reasonable defaults," but you can experiment with others too
algo = Recommender.adapt(user_user)
algo.fit(data.ratings) # this essentially "trains" s user-user CF model.  The ratings data are memorized in a format that is usable for computations
print("Set up a User-User algorithm!")
# Out:
# Set up a User-User algorithm!

# %% [markdown]
# Now that the system has defined clusters, we can feed in reviewer 1's movie reviews.  The User-User algorithm will then find a neighborhood of users similar to my movie ratings. It will look at movies that these similar users have rated that we haven't seen yet. Based on their ratings, it will predict how we may rate that movie if we watched it. Finally, it will order these predictions and print them in descending order and return the top recommendations.
#
# **Step 4.2**

# %%
reviewer1_recs = algo.recommend(-1, num_recs, ratings=pd.Series(reviewer1_rating_dict))  #Here, -1 tells it that it's not an existing user in the set, that we're giving new ratings, while 10 is how many recommendations it should generate

joined_data = reviewer1_recs.join(data.movies['genres'], on='item')      
joined_data = joined_data.join(data.movies['title'], on='item')

joined_data = joined_data[joined_data.columns[2:]]
print("\n\nRECOMMENDED FOR REVIEWER 1 (minimum " + str(minimum_to_include) + " reviews ):")
joined_data
# Out:
# RECOMMENDED FOR REVIEWER 1 (minimum 50000 reviews ):
#                 genres                                              title
# 0                Drama                      Emperor Tomato Ketchup (1971)
# 1          Documentary                     Dreams with Sharp Teeth (2008)
# 2                Drama                                    Wetlands (2011)
# 3            Drama|War  Hitler: A Film from Germany (Hitler - ein Film...
# 4          Documentary  King Cohen: The Wild World of Filmmaker Larry ...
# ..                 ...                                                ...
# 95           Animation                This Unnameable Little Broom (1985)
# 96         Documentary                                       45365 (2010)
# 97               Drama                         Wives and Daughters (1999)
# 98  (no genres listed)                    AC/DC- Let There Be Rock (1980)
# 99             Musical                          Girl Walk: All Day (2011)
#
# [100 rows x 2 columns]

# %% [markdown]
# There are a fair number of documentaries in that list.  Don't get me wrong, I love documentaries.  But I am more interested in finding a good movie on saturday night.  Lets add in some filtering to look for certain genres and/or avoid certain genres.
#
# **Step 4.23**

# %%
genre_to_contain = "" # "Drama|Comedy|(no genres listed)"  # add a value if you only want movies in a specific genre
genre_to_not_contain = "Documentary|Animation" # "Documentary|Horror|Animation"  # add a value if you do not want movies from a specific genre

# FROM THE PREVIOUS BLOCK
filtered_joined_data = reviewer1_recs.join(data.movies['genres'], on='item')      
filtered_joined_data = filtered_joined_data.join(data.movies['title'], on='item')
filtered_joined_data = filtered_joined_data[filtered_joined_data.columns[2:]]
filtered_joined_data = filtered_joined_data.loc[filtered_joined_data['genres'].str.contains(genre_to_contain)]  # Movies MUST contain genre(s)
filtered_joined_data = filtered_joined_data.loc[ ~filtered_joined_data['genres'].str.contains(genre_to_not_contain)] # Movies must NOT contains genre(s))
print("\n\nRECOMMENDED GENRE-SPECIFIC MOVIES FOR REVIEWER 1:")
filtered_joined_data
# Out:
# RECOMMENDED GENRE-SPECIFIC MOVIES FOR REVIEWER 1:
#                             genres  \
# 0                            Drama
# 2                            Drama
# 3                        Drama|War
# 5                            Drama
# 7               (no genres listed)
# 8           Drama|Mystery|Thriller
# 9             Comedy|Drama|Fantasy
# 10                          Comedy
# 12                           Drama
# 13              (no genres listed)
# 14                  Comedy|Fantasy
# 15                    Action|Drama
# 18                           Drama
# 20              (no genres listed)
# 25                           Drama
# 26                    Action|Crime
# 27                          Comedy
# 28           Drama|Musical|Romance
# 29              (no genres listed)
# 33              (no genres listed)
# 34                           Drama
# 36                  Children|Drama
# 39              (no genres listed)
# 42                           Drama
# 44                           Drama
# 46                           Drama
# 47              (no genres listed)
# 49           Drama|Mystery|Romance
# 51                           Drama
# 54              (no genres listed)
# 55                          Comedy
# 61                   Drama|Romance
# 62                  Action|Western
# 63                Children|Fantasy
# 64                          Comedy
# 66             Action|Thriller|War
# 67              (no genres listed)
# 70                           Drama
# 71                          Comedy
# 72                       Drama|War
# 74                          Comedy
# 75                          Comedy
# 77                   Comedy|Sci-Fi
# 80                    Action|Drama
# 81                          Comedy
# 82                          Comedy
# 83              (no genres listed)
# 84             Action|Comedy|Drama
# 85                   Drama|Mystery
# 86                           Drama
# 87              (no genres listed)
# 88              (no genres listed)
# 90                           Drama
# 93  Action|Adventure|Drama|Western
# 94              (no genres listed)
# 97                           Drama
# 98              (no genres listed)
# 99                         Musical
#
#                                                 title
# 0                       Emperor Tomato Ketchup (1971)
# 2                                     Wetlands (2011)
# 3   Hitler: A Film from Germany (Hitler - ein Film...
# 5                       East Wind (Vent d'Est) (1993)
# 7                   We Always Lie to Strangers (2013)
# 8                                 Diamond Dust (2018)
# 9                   The House That Swift Built (1982)
# 10           Assume the Position with Mr. Wuhl (2007)
# 12                                   Blackbird (2014)
# 13              Stephen Fry Live: More Fool Me (2014)
# 14                                   Pastorela (2011)
# 15                               Afraid to Die (1960)
# 18                              Lily Sometimes (2010)
# 20                                   I-Be Area (2007)
# 25                                Bad Spelling (2004)
# 26                            Batman: Dead End (2003)
# 27                Doug Stanhope: Deadbeat Hero (2004)
# 28                                Torch Singer (1933)
# 29  Portrait of a Young Man in Three Movements (1931)
# 33                                Hydrozagadka (1971)
# 34                                 Letter, The (1929)
# 36                                      Masoom (1983)
# 39                                Wasted Youth (2011)
# 42                     If You Were Young: Rage (1970)
# 44                                Sweet Dreams (2016)
# 46                                 Mixed Kebab (2012)
# 47                                 The Capsule (2012)
# 49                                      Oriana (1985)
# 51  Boy Eating the Bird's Food (To agori troei to ...
# 54                Cien niños esperando un tren (1988)
# 55                                  Konopielka (1982)
# 61                       Khamoshi: The Musical (1996)
# 62                      Coffin Full of Dollars (1971)
# 63                      Give the Devil His Due (1984)
# 64  Doug Stanhope: Oslo - Burning the Bridge to No...
# 66  Better Tomorrow III: Love and Death in Saigon,...
# 67                                 Casus Belli (2010)
# 70                                         Uno (2004)
# 71  Holidays by the Sea (Ni à vendre ni à louer) (...
# 72  Then I Sentenced Them All to Death (Atunci i-a...
# 74                Toto, Peppino, and the Hussy (1956)
# 75                 Lewis Black: In God We Rust (2012)
# 77                                      Troops (1997)
# 80                                Emmanuelle 5 (1987)
# 81     Richard Jeni: A Big Steaming Pile of Me (2005)
# 82             Tom Papa: Live in New York City (2011)
# 83                           The Missing Scarf (2013)
# 84                              Pedicab Driver (1989)
# 85                            Pigsty (Porcile) (1969)
# 86                 Do Not Shoot at White Swans (1980)
# 87                   A Midsummer Night's Dream (2016)
# 88                         Don't Talk to Irene (2017)
# 90                                The Mountain (2018)
# 93                             The Hellbenders (1967)
# 94  WWE: 50 Greatest Finishing Moves in WWE Histor...
# 97                         Wives and Daughters (1999)
# 98                    AC/DC- Let There Be Rock (1980)
# 99                          Girl Walk: All Day (2011)
