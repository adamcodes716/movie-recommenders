# %% [markdown]
# This is an example of a collaborative approach to movie recommendations.  A dataset containing a list of movies is created, and then another data set
# containing a single person's reviews is passed in.  The code then finds the nearest neighbors to that user (e.g. people that like the same movies).
# It then predicts movies that the user will like based on their neighbor's likes.

# %% [markdown]
# # Create a virtual environment.  Optional, only needs to be done once.  MUST BE RUN IN THE TERMINAL
# python -m venv .venv
#
# # Active the environment.  On MacOS, WSL, Linux
# source .venv/bin/activate
# # Activiate the environment  On Windows
# .\.venv\Scripts\activate

# %%
# The next line only needs to be run once
# %pip install lenskit
import lenskit.datasets as ds
import pandas as pd
#data = ds.MovieLens('sample-data-small/')
# use the next line for large dataset (25 mill reviews).  You can find this set at https://grouplens.org/datasets/movielens/25m/
data = ds.MovieLens('sample-data-large/')

ratings = data.ratings

# %% [markdown]
# MovieLens stores a user's ID number (the first row few rows look like they're all ratings from user 1), the item's ID (in this case each ID is a different movie)
#
# Step 1.2

# %%
rows_to_show = 50   # <-- Change this number to get back more or less recommendations
data.ratings.head(rows_to_show)  # <-- Try changing "ratings" to "movies", "tags", or "links" to see the kinds of data that's stored in the other MovieLens files
# Out:
#     user  item  rating   timestamp
# 0      1   296     5.0  1147880044
# 1      1   306     3.5  1147868817
# 2      1   307     5.0  1147868828
# 3      1   665     5.0  1147878820
# 4      1   899     3.5  1147868510
# 5      1  1088     4.0  1147868495
# 6      1  1175     3.5  1147868826
# 7      1  1217     3.5  1147878326
# 8      1  1237     5.0  1147868839
# 9      1  1250     4.0  1147868414
# 10     1  1260     3.5  1147877857
# 11     1  1653     4.0  1147868097
# 12     1  2011     2.5  1147868079
# 13     1  2012     2.5  1147868068
# 14     1  2068     2.5  1147869044
# 15     1  2161     3.5  1147868609
# 16     1  2351     4.5  1147877957
# 17     1  2573     4.0  1147878923
# 18     1  2632     5.0  1147878248
# 19     1  2692     5.0  1147869100
# 20     1  2843     4.5  1147868891
# 21     1  3448     4.0  1147868480
# 22     1  3569     5.0  1147879603
# 23     1  3949     5.0  1147868678
# 24     1  4144     5.0  1147868898
# 25     1  4308     3.0  1147868534
# 26     1  4325     5.0  1147878122
# 27     1  4422     3.0  1147869048
# 28     1  4703     4.0  1147869223
# 29     1  4973     4.5  1147869080
# 30     1  5147     4.0  1147877654
# 31     1  5269     0.5  1147879571
# 32     1  5684     2.0  1147879797
# 33     1  5767     5.0  1147878729
# 34     1  5878     4.0  1147868807
# 35     1  5912     3.0  1147878698
# 36     1  5952     4.0  1147868053
# 37     1  6016     5.0  1147869090
# 38     1  6370     4.5  1147869191
# 39     1  6377     4.0  1147868469
# 40     1  6539     3.5  1147868461
# 41     1  6711     5.0  1147868622
# 42     1  6954     3.5  1147869150
# 43     1  7209     4.0  1147877986
# 44     1  7234     4.5  1147868869
# 45     1  7318     2.0  1147879850
# 46     1  7323     3.5  1147869119
# 47     1  7327     3.5  1147868855
# 48     1  7361     5.0  1147880055
# 49     1  7365     4.0  1147869033

# %% [markdown]
# Pull in genre and title from the "movies" file

# %%
joined_data = data.ratings.join(data.movies['genres'], on='item')
joined_data = joined_data.join(data.movies['title'], on='item')
joined_data.head(rows_to_show)
# Out:
#     user  item  rating   timestamp                                 genres  \
# 0      1   296     5.0  1147880044            Comedy|Crime|Drama|Thriller
# 1      1   306     3.5  1147868817                                  Drama
# 2      1   307     5.0  1147868828                                  Drama
# 3      1   665     5.0  1147878820                       Comedy|Drama|War
# 4      1   899     3.5  1147868510                 Comedy|Musical|Romance
# 5      1  1088     4.0  1147868495                  Drama|Musical|Romance
# 6      1  1175     3.5  1147868826                   Comedy|Drama|Romance
# 7      1  1217     3.5  1147878326                              Drama|War
# 8      1  1237     5.0  1147868839                                  Drama
# 9      1  1250     4.0  1147868414                    Adventure|Drama|War
# 10     1  1260     3.5  1147877857               Crime|Film-Noir|Thriller
# 11     1  1653     4.0  1147868097                  Drama|Sci-Fi|Thriller
# 12     1  2011     2.5  1147868079                Adventure|Comedy|Sci-Fi
# 13     1  2012     2.5  1147868068        Adventure|Comedy|Sci-Fi|Western
# 14     1  2068     2.5  1147869044                  Drama|Fantasy|Mystery
# 15     1  2161     3.5  1147868609             Adventure|Children|Fantasy
# 16     1  2351     4.5  1147877957                                  Drama
# 17     1  2573     4.0  1147878923                          Drama|Musical
# 18     1  2632     5.0  1147878248                Adventure|Drama|Mystery
# 19     1  2692     5.0  1147869100                           Action|Crime
# 20     1  2843     4.5  1147868891                         Comedy|Romance
# 21     1  3448     4.0  1147868480                       Comedy|Drama|War
# 22     1  3569     5.0  1147879603                           Comedy|Drama
# 23     1  3949     5.0  1147868678                                  Drama
# 24     1  4144     5.0  1147868898                          Drama|Romance
# 25     1  4308     3.0  1147868534                  Drama|Musical|Romance
# 26     1  4325     5.0  1147878122                                  Drama
# 27     1  4422     3.0  1147869048                                  Drama
# 28     1  4703     4.0  1147869223                                  Drama
# 29     1  4973     4.5  1147869080                         Comedy|Romance
# 30     1  5147     4.0  1147877654                                  Drama
# 31     1  5269     0.5  1147879571                                  Drama
# 32     1  5684     2.0  1147879797                            Documentary
# 33     1  5767     5.0  1147878729                           Comedy|Crime
# 34     1  5878     4.0  1147868807                          Drama|Romance
# 35     1  5912     3.0  1147878698                           Comedy|Crime
# 36     1  5952     4.0  1147868053                      Adventure|Fantasy
# 37     1  6016     5.0  1147869090  Action|Adventure|Crime|Drama|Thriller
# 38     1  6370     4.5  1147869191                   Comedy|Drama|Romance
# 39     1  6377     4.0  1147868469    Adventure|Animation|Children|Comedy
# 40     1  6539     3.5  1147868461        Action|Adventure|Comedy|Fantasy
# 41     1  6711     5.0  1147868622                   Comedy|Drama|Romance
# 42     1  6954     3.5  1147869150     Comedy|Crime|Drama|Mystery|Romance
# 43     1  7209     4.0  1147877986                                 Comedy
# 44     1  7234     4.5  1147868869                                  Drama
# 45     1  7318     2.0  1147879850                                  Drama
# 46     1  7323     3.5  1147869119                           Comedy|Drama
# 47     1  7327     3.5  1147868855                                  Drama
# 48     1  7361     5.0  1147880055                   Drama|Romance|Sci-Fi
# 49     1  7365     4.0  1147869033                                  Drama
#
#                                                 title
# 0                                 Pulp Fiction (1994)
# 1    Three Colors: Red (Trois couleurs: Rouge) (1994)
# 2    Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 3                                  Underground (1995)
# 4                          Singin' in the Rain (1952)
# 5                                Dirty Dancing (1987)
# 6                                 Delicatessen (1991)
# 7                                          Ran (1985)
# 8     Seventh Seal, The (Sjunde inseglet, Det) (1957)
# 9                Bridge on the River Kwai, The (1957)
# 10                                           M (1931)
# 11                                     Gattaca (1997)
# 12                  Back to the Future Part II (1989)
# 13                 Back to the Future Part III (1990)
# 14   Fanny and Alexander (Fanny och Alexander) (1982)
# 15                      NeverEnding Story, The (1984)
# 16    Nights of Cabiria (Notti di Cabiria, Le) (1957)
# 17                                       Tango (1998)
# 18  Saragossa Manuscript, The (Rekopis znaleziony ...
# 19                   Run Lola Run (Lola rennt) (1998)
# 20  Black Cat, White Cat (Crna macka, beli macor) ...
# 21                       Good Morning, Vietnam (1987)
# 22                     Idiots, The (Idioterne) (1998)
# 23                         Requiem for a Dream (2000)
# 24      In the Mood For Love (Fa yeung nin wa) (2000)
# 25                                Moulin Rouge (2001)
# 26                      Night, The (Notte, La) (1960)
# 27     Cries and Whispers (Viskningar och rop) (1972)
# 28                                    Chocolat (1988)
# 29  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 30         Wild Strawberries (Smultronstället) (1957)
# 31            Piano Teacher, The (La pianiste) (2001)
# 32                                  Naqoyqatsi (2002)
# 33                            Teddy Bear (Mis) (1981)
# 34                Talk to Her (Hable con Ella) (2002)
# 35                       Hit the Bank (Vabank) (1981)
# 36      Lord of the Rings: The Two Towers, The (2002)
# 37                City of God (Cidade de Deus) (2002)
# 38  Spanish Apartment, The (L'auberge espagnole) (...
# 39                                Finding Nemo (2003)
# 40  Pirates of the Caribbean: The Curse of the Bla...
# 41                         Lost in Translation (2003)
# 42  Barbarian Invasions, The (Les invasions barbar...
# 43  M. Hulot’s Holiday (Mr. Hulot's Holiday) (Vaca...
# 44                                  Strada, La (1954)
# 45                  Passion of the Christ, The (2004)
# 46                            Good bye, Lenin! (2003)
# 47                                     Persona (1966)
# 48       Eternal Sunshine of the Spotless Mind (2004)
# 49                Noi the Albino (Nói albinói) (2003)

# %% [markdown]
# The movies and ratings have now been loaded.

# %% [markdown]
# ***STEP 2***
#
# Show a list of the top rated movies
#
# **Step 2.1**

# %%
average_ratings = (data.ratings).groupby(['item']).mean()
sorted_avg_ratings = average_ratings.sort_values(by="rating", ascending=False)
joined_data = sorted_avg_ratings.join(data.movies['genres'], on='item')
joined_data = joined_data.join(data.movies['title'], on='item')
joined_data = joined_data[joined_data.columns[1:]]

print("RECOMMENDED FOR ANYBODY:")
joined_data.head(rows_to_show)
# Out:
# RECOMMENDED FOR ANYBODY:
#         rating     timestamp                                genres  \
# item
# 136782     5.0  1.558738e+09                              Thriller
# 186119     5.0  1.558738e+09                              Children
# 137032     5.0  1.436144e+09                        Drama|Thriller
# 184643     5.0  1.558738e+09                              Thriller
# 137038     5.0  1.436144e+09                        Drama|Thriller
# 197231     5.0  1.558738e+09  Crime|Drama|Mystery|Romance|Thriller
# 184669     5.0  1.558738e+09                                Horror
# 137048     5.0  1.436145e+09                                 Drama
# 137050     5.0  1.436145e+09                              Thriller
# 137052     5.0  1.436145e+09                        Drama|Thriller
# 137064     5.0  1.436146e+09                           Crime|Drama
# 197095     5.0  1.558738e+09                         Comedy|Sci-Fi
# 137078     5.0  1.436150e+09                              Thriller
# 158681     5.0  1.558738e+09                        Children|Drama
# 197035     5.0  1.558738e+09                Action|Sci-Fi|Thriller
# 197027     5.0  1.558738e+09                              Thriller
# 184903     5.0  1.539303e+09                           Crime|Drama
# 196959     5.0  1.545877e+09                    (no genres listed)
# 158649     5.0  1.462985e+09                           Documentary
# 137132     5.0  1.558738e+09                        Comedy|Romance
# 185085     5.0  1.520425e+09                    (no genres listed)
# 158378     5.0  1.462651e+09                        Drama|Thriller
# 196845     5.0  1.558738e+09            Adventure|Children|Fantasy
# 137140     5.0  1.558738e+09                    (no genres listed)
# 137148     5.0  1.558738e+09                    (no genres listed)
# 185237     5.0  1.558738e+09               Action|Adventure|Sci-Fi
# 196787     5.0  1.545602e+09                             Drama|War
# 137178     5.0  1.558738e+09                                 Drama
# 185263     5.0  1.520610e+09                           Documentary
# 137194     5.0  1.558738e+09                                Comedy
# 196725     5.0  1.546917e+09              Children|Fantasy|Romance
# 159048     5.0  1.478231e+09           Action|Crime|Drama|Thriller
# 197263     5.0  1.558738e+09                                 Drama
# 159050     5.0  1.472697e+09                    (no genres listed)
# 136878     5.0  1.436067e+09                    (no genres listed)
# 136734     5.0  1.558738e+09                                Comedy
# 136770     5.0  1.558738e+09                    (no genres listed)
# 159135     5.0  1.463925e+09        Action|Adventure|Drama|Romance
# 184335     5.0  1.558738e+09                                Comedy
# 136802     5.0  1.558738e+09                                 Drama
# 136826     5.0  1.435970e+09                                 Drama
# 136853     5.0  1.558738e+09                           Crime|Drama
# 159125     5.0  1.463922e+09                    (no genres listed)
# 184437     5.0  1.558738e+09                          Comedy|Drama
# 184463     5.0  1.558738e+09                          Comedy|Drama
# 136872     5.0  1.436067e+09                    (no genres listed)
# 136876     5.0  1.436067e+09                    (no genres listed)
# 197595     5.0  1.560369e+09           Action|Crime|Drama|Thriller
# 136914     5.0  1.558738e+09                  Crime|Drama|Thriller
# 137026     5.0  1.436143e+09                      Mystery|Thriller
#
#                                        title
# item
# 136782         The Girl is in Trouble (2015)
# 186119                   A Gift Horse (2015)
# 137032           The Perfect Neighbor (2005)
# 184643                     Relentless (2018)
# 137038               The Perfect Wife (2001)
# 197231                     The Harrow (2016)
# 184669                Devil's Whisper (2017)
# 137048                  Perfect Child (2007)
# 137050                      The Rival (2006)
# 137052              A Job to Kill For (2006)
# 137064                 Twisted Desire (1996)
# 197095              From Other Worlds (2004)
# 137078           Stranger in My House (1999)
# 158681                        Courage (2009)
# 197035                   Alien Rising (2013)
# 197027                   Nowhere Mind (2018)
# 184903                       Joy Road (2011)
# 196959                   I Am JFK Jr. (2016)
# 158649               La Soif du Monde (2012)
# 137132             HottieBoombaLottie (2008)
# 185085      The Legend of Earl Durand (1980)
# 158378              Queen of Carthage (2013)
# 196845  Journey to the Christmas Star (2012)
# 137140                     Blue Ridge (2012)
# 137148            Shoot the Messenger (2006)
# 185237                  The Purifiers (2005)
# 196787           The Law and the Fist (1964)
# 137178                 Missing Pieces (2012)
# 185263                     Deaf child (2017)
# 137194                Meeting Spencer (2010)
# 196725                       My Santa (2013)
# 159048                    One Way Out (2002)
# 197263               Dance Baby Dance (2018)
# 159050               The Pilot's Wife (2005)
# 136878                         Paradh (2010)
# 136734                       What Now (2015)
# 136770           Transatlantic Coffee (2012)
# 159135                     The Viking (1931)
# 184335                       Man Camp (2013)
# 136802                  The Historian (2014)
# 136826               The Defiant Ones (1986)
# 136853             Laugh Killer Laugh (2015)
# 159125                 Anybody's Son Will Do
# 184437                  Always Worthy (2016)
# 184463               The Californians (2005)
# 136872                      Zapatlela (1993)
# 136876       The Village Had No Walls (1995)
# 197595              Pitbull: Last Dog (2018)
# 136914                           RISE (2014)
# 137026                  Tainted Blood (1993)

# %% [markdown]
# There are several rare movies here.  It could be the result of having a limited number of reviews.
# Add a "count" column to see how many reviews there are for each movie.

# %%
average_ratings = (data.ratings).groupby('item') \
       .agg(count=('user', 'size'), rating=('rating', 'mean')) \
       .reset_index()

sorted_avg_ratings = average_ratings.sort_values(by="rating", ascending=False)
joined_data = sorted_avg_ratings.join(data.movies['genres'], on='item')
joined_data = joined_data.join(data.movies['title'], on='item')
joined_data = joined_data[joined_data.columns[1:]]


print("RECOMMENDED FOR ANYBODY:")
joined_data.head(rows_to_show)
# Out:
# RECOMMENDED FOR ANYBODY:
#        count  rating                                genres  \
# 29523      1     5.0                              Thriller
# 49654      1     5.0                              Children
# 29643      1     5.0                        Drama|Thriller
# 49041      1     5.0                              Thriller
# 29646      1     5.0                        Drama|Thriller
# 54556      1     5.0  Crime|Drama|Mystery|Romance|Thriller
# 49052      1     5.0                                Horror
# 29651      1     5.0                                 Drama
# 29652      1     5.0                              Thriller
# 29653      1     5.0                        Drama|Thriller
# 29658      1     5.0                           Crime|Drama
# 54498      1     5.0                         Comedy|Sci-Fi
# 29665      1     5.0                              Thriller
# 37904      1     5.0                        Children|Drama
# 54472      1     5.0                Action|Sci-Fi|Thriller
# 54468      1     5.0                              Thriller
# 49151      2     5.0                           Crime|Drama
# 54437      1     5.0                    (no genres listed)
# 37890      1     5.0                           Documentary
# 29684      1     5.0                        Comedy|Romance
# 49236      1     5.0                    (no genres listed)
# 37791      1     5.0                        Drama|Thriller
# 54390      1     5.0            Adventure|Children|Fantasy
# 29688      1     5.0                    (no genres listed)
# 29692      1     5.0                    (no genres listed)
# 49295      1     5.0               Action|Adventure|Sci-Fi
# 54367      1     5.0                             Drama|War
# 29705      1     5.0                                 Drama
# 49303      1     5.0                           Documentary
# 29713      1     5.0                                Comedy
# 54341      1     5.0              Children|Fantasy|Romance
# 38066      1     5.0           Action|Crime|Drama|Thriller
# 54571      1     5.0                                 Drama
# 38067      1     5.0                    (no genres listed)
# 29568      1     5.0                    (no genres listed)
# 29499      1     5.0                                Comedy
# 29517      1     5.0                    (no genres listed)
# 38108      1     5.0        Action|Adventure|Drama|Romance
# 48901      1     5.0                                Comedy
# 29532      1     5.0                                 Drama
# 29544      1     5.0                                 Drama
# 29557      1     5.0                           Crime|Drama
# 38103      1     5.0                    (no genres listed)
# 48947      1     5.0                          Comedy|Drama
# 48957      1     5.0                          Comedy|Drama
# 29565      1     5.0                    (no genres listed)
# 29567      1     5.0                    (no genres listed)
# 54706      1     5.0           Action|Crime|Drama|Thriller
# 29586      1     5.0                  Crime|Drama|Thriller
# 29640      1     5.0                      Mystery|Thriller
#
#                                       title
# 29523         The Girl is in Trouble (2015)
# 49654                   A Gift Horse (2015)
# 29643           The Perfect Neighbor (2005)
# 49041                     Relentless (2018)
# 29646               The Perfect Wife (2001)
# 54556                     The Harrow (2016)
# 49052                Devil's Whisper (2017)
# 29651                  Perfect Child (2007)
# 29652                      The Rival (2006)
# 29653              A Job to Kill For (2006)
# 29658                 Twisted Desire (1996)
# 54498              From Other Worlds (2004)
# 29665           Stranger in My House (1999)
# 37904                        Courage (2009)
# 54472                   Alien Rising (2013)
# 54468                   Nowhere Mind (2018)
# 49151                       Joy Road (2011)
# 54437                   I Am JFK Jr. (2016)
# 37890               La Soif du Monde (2012)
# 29684             HottieBoombaLottie (2008)
# 49236      The Legend of Earl Durand (1980)
# 37791              Queen of Carthage (2013)
# 54390  Journey to the Christmas Star (2012)
# 29688                     Blue Ridge (2012)
# 29692            Shoot the Messenger (2006)
# 49295                  The Purifiers (2005)
# 54367           The Law and the Fist (1964)
# 29705                 Missing Pieces (2012)
# 49303                     Deaf child (2017)
# 29713                Meeting Spencer (2010)
# 54341                       My Santa (2013)
# 38066                    One Way Out (2002)
# 54571               Dance Baby Dance (2018)
# 38067               The Pilot's Wife (2005)
# 29568                         Paradh (2010)
# 29499                       What Now (2015)
# 29517           Transatlantic Coffee (2012)
# 38108                     The Viking (1931)
# 48901                       Man Camp (2013)
# 29532                  The Historian (2014)
# 29544               The Defiant Ones (1986)
# 29557             Laugh Killer Laugh (2015)
# 38103                 Anybody's Son Will Do
# 48947                  Always Worthy (2016)
# 48957               The Californians (2005)
# 29565                      Zapatlela (1993)
# 29567       The Village Had No Walls (1995)
# 54706              Pitbull: Last Dog (2018)
# 29586                           RISE (2014)
# 29640                  Tainted Blood (1993)

# %% [markdown]
# We probably don't want movies that don't have many reviews
#
# **Step 2.2**

# %%
minimum_to_include = 50 #<-- You can try changing this minimum to include movies rated by fewer or more people

average_ratings = (data.ratings).groupby(['item']).mean()
rating_counts = (data.ratings).groupby(['item']).count()
average_ratings = average_ratings.loc[rating_counts['rating'] > minimum_to_include]
sorted_avg_ratings = average_ratings.sort_values(by="rating", ascending=False)
joined_data = sorted_avg_ratings.join(data.movies['genres'], on='item')
joined_data = joined_data.join(data.movies['title'], on='item')
joined_data = joined_data[joined_data.columns[3:]]

print("RECOMMENDED FOR ANYBODY:")
joined_data.head(rows_to_show)
# Out:
# RECOMMENDED FOR ANYBODY:
#                                                  genres  \
# item
# 171011                                      Documentary
# 159817                                      Documentary
# 318                                         Crime|Drama
# 170705                                 Action|Drama|War
# 171495                               (no genres listed)
# 858                                         Crime|Drama
# 179135                                      Documentary
# 50                               Crime|Mystery|Thriller
# 198185                                    Drama|Mystery
# 1221                                        Crime|Drama
# 163809                        Adventure|Animation|Drama
# 176601                               (no genres listed)
# 2019                             Action|Adventure|Drama
# 147250                               (no genres listed)
# 142115                                      Documentary
# 527                                           Drama|War
# 1203                                              Drama
# 904                                    Mystery|Thriller
# 159819                                      Documentary
# 2959                        Action|Crime|Drama|Thriller
# 1193                                              Drama
# 750                                          Comedy|War
# 5618                        Adventure|Animation|Fantasy
# 166024                               (no genres listed)
# 202439                                     Comedy|Drama
# 912                                       Drama|Romance
# 922                             Drama|Film-Noir|Romance
# 1212                         Film-Noir|Mystery|Thriller
# 44555                            Drama|Romance|Thriller
# 172577                Animation|Children|Comedy|Fantasy
# 1178                                          Drama|War
# 908           Action|Adventure|Mystery|Romance|Thriller
# 3435                              Crime|Drama|Film-Noir
# 175981                                            Drama
# 296                         Comedy|Crime|Drama|Thriller
# 182723                               (no genres listed)
# 100044                                      Documentary
# 6016              Action|Adventure|Crime|Drama|Thriller
# 1213                                        Crime|Drama
# 3030                                   Action|Adventure
# 170777                        Animation|Children|Comedy
# 926                                               Drama
# 179173                                 Animation|Comedy
# 58559                           Action|Crime|Drama|IMAX
# 930                          Film-Noir|Romance|Thriller
# 1260                           Crime|Film-Noir|Thriller
# 1284                            Crime|Film-Noir|Mystery
# 1252                   Crime|Film-Noir|Mystery|Thriller
# 79132   Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX
# 26082                                             Drama
#
#                                                     title
# item
# 171011                             Planet Earth II (2016)
# 159817                                Planet Earth (2006)
# 318                      Shawshank Redemption, The (1994)
# 170705                            Band of Brothers (2001)
# 171495                                             Cosmos
# 858                                 Godfather, The (1972)
# 179135                              Blue Planet II (2017)
# 50                             Usual Suspects, The (1995)
# 198185                                  Twin Peaks (1989)
# 1221                       Godfather: Part II, The (1974)
# 163809                        Over the Garden Wall (2013)
# 176601                                       Black Mirror
# 2019          Seven Samurai (Shichinin no samurai) (1954)
# 147250  The Adventures of Sherlock Holmes and Doctor W...
# 142115                             The Blue Planet (2001)
# 527                               Schindler's List (1993)
# 1203                                  12 Angry Men (1957)
# 904                                    Rear Window (1954)
# 159819                                        Life (2009)
# 2959                                    Fight Club (1999)
# 1193               One Flew Over the Cuckoo's Nest (1975)
# 750     Dr. Strangelove or: How I Learned to Stop Worr...
# 5618    Spirited Away (Sen to Chihiro no kamikakushi) ...
# 166024                                    Whiplash (2013)
# 202439                                    Parasite (2019)
# 912                                     Casablanca (1942)
# 922         Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 1212                                Third Man, The (1949)
# 44555   Lives of Others, The (Das leben der Anderen) (...
# 172577                Last Year's Snow Was Falling (1983)
# 1178                                Paths of Glory (1957)
# 908                             North by Northwest (1959)
# 3435                              Double Indemnity (1944)
# 175981                            Twelve Angry Men (1954)
# 296                                   Pulp Fiction (1994)
# 182723                        Cosmos: A Spacetime Odissey
# 100044                                Human Planet (2011)
# 6016                  City of God (Cidade de Deus) (2002)
# 1213                                    Goodfellas (1990)
# 3030                                       Yojimbo (1961)
# 170777                        There Once Was a Dog (1982)
# 926                                  All About Eve (1950)
# 179173                           Rabbit of Seville (1950)
# 58559                             Dark Knight, The (2008)
# 930                                      Notorious (1946)
# 1260                                             M (1931)
# 1284                                Big Sleep, The (1946)
# 1252                                     Chinatown (1974)
# 79132                                    Inception (2010)
# 26082                           Harakiri (Seppuku) (1962)

# %% [markdown]
# Lets show the top movies for someone looking for a specific genre

# %%
genre = "Romance"
average_ratings = (data.ratings).groupby(['item']).mean()
rating_counts = (data.ratings).groupby(['item']).count()
average_ratings = average_ratings.loc[rating_counts['rating'] > minimum_to_include]
average_ratings = average_ratings.join(data.movies['genres'], on='item')
average_ratings = average_ratings.loc[average_ratings['genres'].str.contains(genre)]

sorted_avg_ratings = average_ratings.sort_values(by="rating", ascending=False)
joined_data = sorted_avg_ratings.join(data.movies['title'], on='item')
joined_data = joined_data[joined_data.columns[3:]]
print("RECOMMENDED FOR A " + genre.upper() + " MOVIE FAN:")
joined_data.head(rows_to_show)
# Out:
# RECOMMENDED FOR A ROMANCE MOVIE FAN:
#                                            genres  \
# item
# 912                                 Drama|Romance
# 922                       Drama|Film-Noir|Romance
# 44555                      Drama|Romance|Thriller
# 908     Action|Adventure|Mystery|Romance|Thriller
# 930                    Film-Noir|Romance|Thriller
# 2324                     Comedy|Drama|Romance|War
# 898                          Comedy|Drama|Romance
# 26587                         Crime|Drama|Romance
# 127052                       Comedy|Crime|Romance
# 141818               Comedy|Drama|Fantasy|Romance
# 905                                Comedy|Romance
# 1197      Action|Adventure|Comedy|Fantasy|Romance
# 2920                                Drama|Romance
# 903                Drama|Mystery|Romance|Thriller
# 98491                    Animation|Comedy|Romance
# 170355                      Drama|Mystery|Romance
# 3307                         Comedy|Drama|Romance
# 1224                     Action|Drama|Romance|War
# 2858                                Drama|Romance
# 163134            Animation|Drama|Fantasy|Romance
# 4973                               Comedy|Romance
# 951                                Comedy|Romance
# 2935                               Comedy|Romance
# 31658         Adventure|Animation|Fantasy|Romance
# 147196                             Comedy|Romance
# 3462                         Comedy|Drama|Romance
# 166291                    Animation|Drama|Romance
# 107412                             Comedy|Romance
# 158783                     Drama|Romance|Thriller
# 1704                                Drama|Romance
# 928                Drama|Mystery|Romance|Thriller
# 7361                         Drama|Romance|Sci-Fi
# 969                  Adventure|Comedy|Romance|War
# 916                          Comedy|Drama|Romance
# 899                        Comedy|Musical|Romance
# 1244                         Comedy|Drama|Romance
# 356                      Comedy|Drama|Romance|War
# 911         Comedy|Crime|Mystery|Romance|Thriller
# 118302               Comedy|Drama|Musical|Romance
# 3629                     Adventure|Comedy|Romance
# 2843                               Comedy|Romance
# 1230                               Comedy|Romance
# 4144                                Drama|Romance
# 945                        Comedy|Musical|Romance
# 118166                       Comedy|Drama|Romance
# 909                          Comedy|Drama|Romance
# 953                Children|Drama|Fantasy|Romance
# 1247                         Comedy|Drama|Romance
# 2936                     Adventure|Comedy|Romance
# 28                                  Drama|Romance
#
#                                                     title
# item
# 912                                     Casablanca (1942)
# 922         Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 44555   Lives of Others, The (Das leben der Anderen) (...
# 908                             North by Northwest (1959)
# 930                                      Notorious (1946)
# 2324           Life Is Beautiful (La Vita è bella) (1997)
# 898                        Philadelphia Story, The (1940)
# 26587                     Decalogue, The (Dekalog) (1989)
# 127052   Operation 'Y' & Other Shurik's Adventures (1965)
# 141818                            Ordinary Miracle (1978)
# 905                          It Happened One Night (1934)
# 1197                           Princess Bride, The (1987)
# 2920    Children of Paradise (Les enfants du paradis) ...
# 903                                        Vertigo (1958)
# 98491                                     Paperman (2012)
# 170355                              Mulholland Dr. (1999)
# 3307                                   City Lights (1931)
# 1224                                       Henry V (1989)
# 2858                               American Beauty (1999)
# 163134                                  Your Name. (2016)
# 4973    Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 951                                His Girl Friday (1940)
# 2935                                 Lady Eve, The (1941)
# 31658   Howl's Moving Castle (Hauru no ugoku shiro) (2...
# 147196                                   The Girls (1961)
# 3462                                  Modern Times (1936)
# 166291                              A Silent Voice (2016)
# 107412  Kidnapping, Caucasian Style (Kavkazskaya plenn...
# 158783                              The Handmaiden (2016)
# 1704                             Good Will Hunting (1997)
# 928                                        Rebecca (1940)
# 7361         Eternal Sunshine of the Spotless Mind (2004)
# 969                             African Queen, The (1951)
# 916                                  Roman Holiday (1953)
# 899                            Singin' in the Rain (1952)
# 1244                                     Manhattan (1979)
# 356                                   Forrest Gump (1994)
# 911                                        Charade (1963)
# 118302                         The Pokrovsky Gates (1983)
# 3629                                Gold Rush, The (1925)
# 2843    Black Cat, White Cat (Crna macka, beli macor) ...
# 1230                                    Annie Hall (1977)
# 4144        In the Mood For Love (Fa yeung nin wa) (2000)
# 945                                        Top Hat (1935)
# 118166                                     Courier (1987)
# 909                                 Apartment, The (1960)
# 953                          It's a Wonderful Life (1946)
# 1247                                 Graduate, The (1967)
# 2936                            Sullivan's Travels (1941)
# 28                                      Persuasion (1995)

# %% [markdown]
# STEP 3
#
# Step 3 is personalizing our recommender system AI based on a user's reviews. The sample format can be found here:  https://github.com/crash-course-ai/lab4-recommender-systems/blob/master/reviewer1-movie-ratings.csv
#
# This data needs to be in a specific format (see here:  https://lkpy.lenskit.org/en/stable/interfaces.html#lenskit.algorithms.Recommender.recommend).
# Also, be sure that the "ratings" column is out of 5 stars.
#
# Step 3.1

# %%
import csv

reviewer1_rating_dict = {}
reviewer2_rating_dict = {}

#with open("/content/lab4-recommender-systems/reviewer1-movie-ratings.csv", newline='') as csvfile:
with open("sample-data-small/reviewer1-movie-ratings.csv", newline='') as csvfile:
  ratings_reader = csv.DictReader(csvfile)
  for row in ratings_reader:
    if ((row['ratings'] != "") and (float(row['ratings']) > 0) and (float(row['ratings']) < 6)):
      reviewer1_rating_dict.update({int(row['item']): float(row['ratings'])})
      
#with open("/content/lab4-recommender-systems/reviewer2-movie-ratings.csv", newline='') as csvfile:
with open("sample-data-small/reviewer2-movie-ratings.csv", newline='') as csvfile:
  ratings_reader = csv.DictReader(csvfile)
  for row in ratings_reader:
    if ((row['ratings'] != "") and (float(row['ratings']) > 0) and (float(row['ratings']) < 6)):
      reviewer2_rating_dict.update({int(row['item']): float(row['ratings'])})
     
print("Rating dictionaries assembled!")
print("Sanity check:")
print("\tReviewer 1's rating for the first movie is " + str(list(reviewer1_rating_dict.values())[0]))
# Out:
# Rating dictionaries assembled!
# Sanity check:
# 	Reviewer 1's rating for the first movie is 3.5

# %% [markdown]
# Step 4
# We will use UserUser from Lenskit to try to find reviewers (neighbors) that like the same movies that I like.
# As part of this search, we will set a max and min number of neighbors.

# %%
from lenskit.algorithms import Recommender
from lenskit.algorithms.user_knn import UserUser

num_recs = 25  #<---- This is the number of recommendations to generate. You can change this if you want to see more recommendations

user_user = UserUser(15, min_nbrs=3) #These two numbers set the minimum (3) and maximum (15) number of neighbors to consider. These are considered "reasonable defaults," but you can experiment with others too
algo = Recommender.adapt(user_user)
algo.fit(data.ratings) # this essentially "trains" s user-user CF model.  The ratings data are memorized in a format that is usable for computations
print("Set up a User-User algorithm!")
# Out:
# Set up a User-User algorithm!

# %% [markdown]
# Now that the system has defined clusters, we can feed in reviewer 1's movie reviews.  The User-User algorithm will then find a neighborhood of users similar to my movie ratings. It will look at movies that these similar users have rated that we haven't seen yet. Based on their ratings, it will predict how we may rate that movie if we watched it. Finally, it will order these predictions and print them in descending order and return the top recommendations.
#
# **Step 4.2**

# %%
reviewer1_recs = algo.recommend(-1, num_recs, ratings=pd.Series(reviewer1_rating_dict))  #Here, -1 tells it that it's not an existing user in the set, that we're giving new ratings, while 10 is how many recommendations it should generate

joined_data = reviewer1_recs.join(data.movies['genres'], on='item')      
joined_data = joined_data.join(data.movies['title'], on='item')
joined_data = joined_data[joined_data.columns[2:]]
print("\n\nRECOMMENDED FOR REVIEWER 1:")
joined_data
# Out:
# RECOMMENDED FOR REVIEWER 1:
#                      genres                                     title
# 0               Documentary          Fifi Howls from Happiness (2013)
# 1                 Animation                   Visions of Frank (2007)
# 2            Comedy|Romance                  All About My Wife (2012)
# 3               Documentary                            Marlene (1984)
# 4        (no genres listed)         We Always Lie to Strangers (2013)
# 5                     Drama               The Deserted Station (2002)
# 6               Documentary                 Dial H-I-S-T-O-R-Y (1997)
# 7        (no genres listed)                                Ken (1964)
# 8                     Drama                    Moth, The (Cma) (1980)
# 9        (no genres listed)                             Mother (2016)
# 10          Animation|Drama                 The Tragedy of Man (2011)
# 11          Horror|Thriller                        The Godsend (1980)
# 12                   Comedy       Doug Stanhope: Deadbeat Hero (2004)
# 13              Documentary       The Society of the Spectacle (1973)
# 14       (no genres listed)  Social Life of Small Urban Spaces (1988)
# 15              Documentary       Black Sabbath: Never Say Die (1978)
# 16       (no genres listed)                          I-Be Area (2007)
# 17              Documentary            Dreams with Sharp Teeth (2008)
# 18              Documentary                          Unmatched (2010)
# 19              Documentary                         Obey Giant (2017)
# 20           Comedy|Romance                             B-Side (2013)
# 21  Adventure|Drama|Mystery                       Gang of Four (1989)
# 22       (no genres listed)       Cien niños esperando un tren (1988)
# 23       (no genres listed)                                    Cosmos
# 24              Documentary              Story of Science, The (2010)

# %% [markdown]
# There are a fair number of documentaries in that list.  Don't get me wrong, I love documentaries.  But I am more interested in finding a good movie on saturday night.  Lets add in some filtering.
#
# **Step 4.23**

# %%
genre_to_contain = "" # "Drama|Comedy|(no genres listed)"  # add a value if you only want movies in a specific genre
genre_to_not_contain = "Documentary|Horror|Animation"  # add a value if you do not want movies from a specific genre

# FROM THE PREVIOUS BLOCK
filtered_joined_data = reviewer1_recs.join(data.movies['genres'], on='item')      
filtered_joined_data = filtered_joined_data.join(data.movies['title'], on='item')
filtered_joined_data = filtered_joined_data[filtered_joined_data.columns[2:]]
filtered_joined_data = filtered_joined_data.loc[filtered_joined_data['genres'].str.contains(genre_to_contain)]  # Movies MUST contain genre(s)
filtered_joined_data = filtered_joined_data.loc[ ~filtered_joined_data['genres'].str.contains(genre_to_not_contain)] # Movies must NOT contains genre(s))
print("\n\nRECOMMENDED GENRE-SPECIFIC MOVIES FOR REVIEWER 1:")
filtered_joined_data
# Out:
# RECOMMENDED GENRE-SPECIFIC MOVIES FOR REVIEWER 1:
#                      genres                                     title
# 2            Comedy|Romance                  All About My Wife (2012)
# 4        (no genres listed)         We Always Lie to Strangers (2013)
# 5                     Drama               The Deserted Station (2002)
# 7        (no genres listed)                                Ken (1964)
# 8                     Drama                    Moth, The (Cma) (1980)
# 9        (no genres listed)                             Mother (2016)
# 12                   Comedy       Doug Stanhope: Deadbeat Hero (2004)
# 14       (no genres listed)  Social Life of Small Urban Spaces (1988)
# 16       (no genres listed)                          I-Be Area (2007)
# 20           Comedy|Romance                             B-Side (2013)
# 21  Adventure|Drama|Mystery                       Gang of Four (1989)
# 22       (no genres listed)       Cien niños esperando un tren (1988)
# 23       (no genres listed)                                    Cosmos
